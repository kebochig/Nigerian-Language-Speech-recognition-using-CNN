# %%
import os
import numpy as np
import pandas as pd
from scipy.io import wavfile
import matplotlib.pyplot as plt
from scipy.signal import stft
from scipy import signal
from scipy.fftpack import dct
from glob import glob
import librosa
import librosa.display
# %matplotlib inline

# %%
# name parent directory
DIR = 'C:/Users.../Dataset'

# %%
LABELS = 'English Yoruba Igbo'.split()

# %%
# Catalogue files in a tabular format

wav_files = glob(os.path.join(DIR, '*/*wav'))
wav_files = [x.split(sep='\\')[1] + '/' + x.split(sep='\\')[2] for x in wav_files]

data = []
for e in wav_files:            
    label, name = e.split('/')
    if label in LABELS:
        label_id = LABELS.index(label)
        fle = os.path.join(DIR, e)

        sample = (label, label_id, name, fle)
        data.append(sample)
# Data Frames with samples' labels and paths     
df = pd.DataFrame(data, columns = ['label', 'label_id', 'user_id', 'wav_file'])

# %%
df
# Out:
#         label  label_id                user_id  \
# 0     English         0       arctic_a0001.wav
# 1     English         0       arctic_a0002.wav
# 2     English         0       arctic_a0003.wav
# 3     English         0       arctic_a0004.wav
# 4     English         0       arctic_a0005.wav
# 5     English         0       arctic_a0006.wav
# 6     English         0       arctic_a0007.wav
# 7     English         0       arctic_a0008.wav
# 8     English         0       arctic_a0009.wav
# 9     English         0       arctic_a0010.wav
# 10    English         0       arctic_a0011.wav
# 11    English         0       arctic_a0012.wav
# 12    English         0       arctic_a0013.wav
# 13    English         0       arctic_a0014.wav
# 14    English         0       arctic_a0015.wav
# 15    English         0       arctic_a0016.wav
# 16    English         0       arctic_a0017.wav
# 17    English         0       arctic_a0018.wav
# 18    English         0       arctic_a0019.wav
# 19    English         0       arctic_a0020.wav
# 20    English         0       arctic_a0021.wav
# 21    English         0       arctic_a0022.wav
# 22    English         0       arctic_a0023.wav
# 23    English         0       arctic_a0024.wav
# 24    English         0       arctic_a0025.wav
# 25    English         0       arctic_a0026.wav
# 26    English         0       arctic_a0027.wav
# 27    English         0       arctic_a0028.wav
# 28    English         0       arctic_a0029.wav
# 29    English         0       arctic_a0030.wav
# ...       ...       ...                    ...
# 2067   Yoruba         1  Yoruba TESTSET 72.wav
# 2068   Yoruba         1  Yoruba TESTSET 73.wav
# 2069   Yoruba         1  Yoruba TESTSET 74.wav
# 2070   Yoruba         1  Yoruba TESTSET 75.wav
# 2071   Yoruba         1  Yoruba TESTSET 76.wav
# 2072   Yoruba         1  Yoruba TESTSET 77.wav
# 2073   Yoruba         1  Yoruba TESTSET 78.wav
# 2074   Yoruba         1  Yoruba TESTSET 79.wav
# 2075   Yoruba         1   Yoruba TESTSET 8.wav
# 2076   Yoruba         1  Yoruba TESTSET 80.wav
# 2077   Yoruba         1  Yoruba TESTSET 81.wav
# 2078   Yoruba         1  Yoruba TESTSET 82.wav
# 2079   Yoruba         1  Yoruba TESTSET 83.wav
# 2080   Yoruba         1  Yoruba TESTSET 84.wav
# 2081   Yoruba         1  Yoruba TESTSET 85.wav
# 2082   Yoruba         1  Yoruba TESTSET 86.wav
# 2083   Yoruba         1  Yoruba TESTSET 87.wav
# 2084   Yoruba         1  Yoruba TESTSET 88.wav
# 2085   Yoruba         1  Yoruba TESTSET 89.wav
# 2086   Yoruba         1   Yoruba TESTSET 9.wav
# 2087   Yoruba         1  Yoruba TESTSET 90.wav
# 2088   Yoruba         1  Yoruba TESTSET 91.wav
# 2089   Yoruba         1  Yoruba TESTSET 92.wav
# 2090   Yoruba         1  Yoruba TESTSET 93.wav
# 2091   Yoruba         1  Yoruba TESTSET 94.wav
# 2092   Yoruba         1  Yoruba TESTSET 95.wav
# 2093   Yoruba         1  Yoruba TESTSET 96.wav
# 2094   Yoruba         1  Yoruba TESTSET 97.wav
# 2095   Yoruba         1  Yoruba TESTSET 98.wav
# 2096   Yoruba         1  Yoruba TESTSET 99.wav
#
#                                                wav_file
# 0     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 1     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 3     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 4     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 5     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 6     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 7     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 8     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 9     C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 10    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 11    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 12    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 13    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 14    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 15    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 16    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 17    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 18    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 19    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 20    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 21    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 22    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 23    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 24    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 25    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 26    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 27    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 28    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 29    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# ...                                                 ...
# 2067  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2068  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2069  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2070  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2071  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2072  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2073  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2074  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2075  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2076  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2077  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2078  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2079  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2080  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2081  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2082  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2083  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2084  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2085  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2086  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2087  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2088  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2089  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2090  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2091  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2092  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2093  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2094  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2095  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2096  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
#
# [2097 rows x 4 columns]

# %%
# reshuffle table 
datf = df.sample(frac=1)
datf.reset_index(drop=True,inplace=True)

# %%
print('Shape: ',datf.shape)
datf
# Out:
# Shape:  (2097, 4)
#         label  label_id                                 user_id  \
# 0      Yoruba         1                   Yoruba TESTSET 31.wav
# 1        Igbo         2                  IgboThirdRound- 21.wav
# 2      Yoruba         1                Yoruba PART two - 93.wav
# 3      Yoruba         1              Yoruba PART Four - 122.wav
# 4      Yoruba         1              Yoruba PART three - 22.wav
# 5      Yoruba         1              Yoruba PART three - 34.wav
# 6        Igbo         2               IgboTestSetSecond- 58.wav
# 7        Igbo         2                              Igbo 6.wav
# 8      Yoruba         1              Yoruba PART three - 36.wav
# 9      Yoruba         1              Yoruba PART Four - 189.wav
# 10       Igbo         2                  IgboSecondRound-94.wav
# 11    English         0                             rai0002.wav
# 12       Igbo         2                  Igbo Part two - 24.wav
# 13    English         0                            com_0179.wav
# 14    English         0                        arctic_a0184.wav
# 15       Igbo         2                  IgboThirdRound- 43.wav
# 16       Igbo         2                  Igbo Part two - 55.wav
# 17       Igbo         2                      IgboTestSet-62.wav
# 18     Yoruba         1               Yoruba PART Four - 70.wav
# 19     Yoruba         1             Yoruba SecondTESTSET 69.wav
# 20     Yoruba         1                Yoruba PART two - 18.wav
# 21       Igbo         2                              Igbo 2.wav
# 22       Igbo         2  obiwanne 14.9.14 - Part_2 DENOISED.wav
# 23    English         0                            com_0329.wav
# 24    English         0                            com_0230.wav
# 25    English         0                        arctic_a0001.wav
# 26       Igbo         2                  Igbo Part two - 12.wav
# 27       Igbo         2                      IgboTestSet-96.wav
# 28       Igbo         2                   IgboThirdRound- 1.wav
# 29    English         0                        arctic_a0094.wav
# ...       ...       ...                                     ...
# 2067   Yoruba         1                Yoruba PART two - 36.wav
# 2068   Yoruba         1              Yoruba PART three - 27.wav
# 2069     Igbo         2                      IgboTestSet-64.wav
# 2070  English         0                        arctic_a0155.wav
# 2071     Igbo         2                   Igbo Part two - 8.wav
# 2072   Yoruba         1                 Yoruba PART two - 3.wav
# 2073  English         0                            com_0128.wav
# 2074   Yoruba         1               Yoruba PART Four - 49.wav
# 2075  English         0                            com_0135.wav
# 2076  English         0                        arctic_a0087.wav
# 2077     Igbo         2               IgboTestSetSecond- 36.wav
# 2078  English         0                            com_0137.wav
# 2079   Yoruba         1             Yoruba PART three - 119.wav
# 2080   Yoruba         1                           Yoruba 13.wav
# 2081  English         0                        arctic_a0134.wav
# 2082  English         0                        arctic_a0036.wav
# 2083  English         0                            com_0158.wav
# 2084   Yoruba         1                           Yoruba 35.wav
# 2085     Igbo         2                  IgboThirdRound- 84.wav
# 2086  English         0                            com_0190.wav
# 2087  English         0                            com_0221.wav
# 2088  English         0                            com_0196.wav
# 2089  English         0                            com_0074.wav
# 2090  English         0                        arctic_a0052.wav
# 2091  English         0                            com_0357.wav
# 2092  English         0                            com_0356.wav
# 2093  English         0                        arctic_a0144.wav
# 2094   Yoruba         1             Yoruba SecondTESTSET 65.wav
# 2095     Igbo         2                  IgboSecondRound-93.wav
# 2096   Yoruba         1              Yoruba PART three - 11.wav
#
#                                                wav_file
# 0     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 1     C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 3     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 4     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 5     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 6     C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 7     C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 8     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 9     C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 10    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 11    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 12    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 13    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 14    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 15    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 16    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 17    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 18    C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 19    C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 20    C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 21    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 22    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/o...
# 23    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 24    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 25    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 26    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 27    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 28    C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 29    C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# ...                                                 ...
# 2067  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2068  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2069  C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2070  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2071  C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2072  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2073  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2074  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2075  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2076  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2077  C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2078  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2079  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2080  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2081  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2082  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2083  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2084  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2085  C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2086  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2087  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2088  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2089  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2090  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2091  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2092  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2093  C:/Users/keboc/Documents/Gideon/Dataset\Englis...
# 2094  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
# 2095  C:/Users/keboc/Documents/Gideon/Dataset\Igbo/I...
# 2096  C:/Users/keboc/Documents/Gideon/Dataset\Yoruba...
#
# [2097 rows x 4 columns]

# %%
# English wave Spectagram example

y, sr = librosa.load(datf[datf.label=='English'].wav_file.values[9],duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)

print(ps.shape)

librosa.display.specshow(ps, y_axis='mel', x_axis='time')
# Out:
# (128, 128)

# %%
# Yoruba wave Spectagram example

y, sr = librosa.load(datf[datf.label=='Yoruba'].wav_file.values[8],duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)

print(ps.shape)

librosa.display.specshow(ps, y_axis='mel', x_axis='time')
# Out:
# (128, 128)

# %%
# Igbo wave Spectagram example

y, sr = librosa.load(datf[datf.label=='Igbo'].wav_file.values[13],duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)

print(ps.shape)

librosa.display.specshow(ps, y_axis='mel', x_axis='time')
# Out:
# (128, 128)

# %%
# Convert files to mel-spectogrm and save in array Data

Data = [] 

for row in datf.itertuples():
    y, sr = librosa.load(row.wav_file, duration=2.97)  
    ps = librosa.feature.melspectrogram(y=y, sr=sr)
    # Discard samples without uniform size
    if ps.shape != (128, 128): continue
    Data.append( (ps, row.label_id) )

# %%
print("Number of samples: ", len(Data))
# Out:
# Number of samples:  1797

# %%
# SAmple of the representation
Data[1007]
# Out:
# (array([[2.19802913e-03, 3.46448998e-03, 1.69691533e-02, ...,
#          9.90695479e-03, 4.86343288e-03, 2.02400266e-03],
#         [1.21589574e-03, 5.09247911e-03, 2.30566232e-02, ...,
#          7.46479251e-03, 3.66490262e-03, 5.05562177e-03],
#         [1.44038994e-03, 1.72524267e-03, 3.20529697e-03, ...,
#          1.25191813e-03, 1.16377785e-03, 1.18347879e-03],
#         ...,
#         [1.28034086e-08, 3.20084089e-09, 6.57833285e-18, ...,
#          2.74610949e-18, 1.22509686e-13, 1.37617666e-09],
#         [1.25136107e-08, 3.12839196e-09, 7.86800898e-18, ...,
#          3.56454375e-18, 1.19572532e-13, 1.34313673e-09],
#         [1.23319585e-08, 3.08297896e-09, 3.84134471e-18, ...,
#          2.84991219e-18, 1.17773267e-13, 1.32284849e-09]]), 0)

# %%
import keras
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
import sklearn
from sklearn.model_selection import train_test_split

dataset = Data
x,y = zip(*dataset)

# Split train and test datset

train, test, labels_train, labels_test = sklearn.model_selection.train_test_split(x, y, train_size=0.80)
print('Size of train set', np.shape(labels_train))
print('Size of test set', np.shape(labels_test))

# Reshape for CNN input
X_train = np.array([x.reshape( (128, 128, 1) ) for x in train])
X_test = np.array([x.reshape( (128, 128, 1) ) for x in test])
# Out:
# Size of train set (1437,)
# Size of test set (360,)
# c:\users\keboc\anaconda3\envs\tensorflow_1.8\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
input_shape=(128, 128, 1)

# %%
# One-Hot encoding for classes
encoder = LabelEncoder()
encoder.fit(labels_train)
y_train = encoder.transform(labels_train)
encoder.fit(labels_test)
y_test = encoder.transform(labels_test)

y_train = np.array(keras.utils.to_categorical(y_train, len(LABELS)))
y_test = np.array(keras.utils.to_categorical(y_test, len(LABELS)))

# %%
# Build model

# %%
from keras.layers import Activation, Dense, Dropout, Conv2D, \
                         Flatten, MaxPooling2D, BatchNormalization
from keras.layers import Input, Dense, Dropout, Flatten,Reshape
from keras.layers import LSTM, Bidirectional
from keras.models import Model, load_model
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint

# %%
def deep_cnn(features_shape, num_classes, act='relu'):

     # Input
    x = Input(name='inputs', shape=features_shape, dtype='float32')
    o = x
    
    # Block 1
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block1_conv', input_shape=features_shape)(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block1_pool')(o)
    o = BatchNormalization(name='block1_norm')(o)
    
    # Block 2
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block2_conv')(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block2_pool')(o)
    o = BatchNormalization(name='block2_norm')(o)

    # Block 3
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block3_conv')(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block3_pool')(o)
    o = BatchNormalization(name='block3_norm')(o)
    
    # Block 4
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block4_conv')(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block4_pool')(o)
    o = BatchNormalization(name='block4_norm')(o)
    
    # Block 5
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block5_conv')(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block5_pool')(o)
    o = BatchNormalization(name='block5_norm')(o)
    
    # Block 6
    o = Conv2D(32, (3, 3), activation=act, padding='same', strides=1, name='block6_conv')(o)
    o = MaxPooling2D((3, 3), strides=(2,2), padding='same', name='block6_pool')(o)
    o = BatchNormalization(name='block6_norm')(o)
    
    
     #CNN TO LSTM 
    o = Reshape(target_shape=((2, 64)), name='reshape')(o)  
    o = Dense(64, activation='relu', kernel_initializer='he_normal', name='dense1')(o) 

    
    o = Bidirectional(LSTM(100,dropout=0.2,return_sequences=True, recurrent_dropout=0.2))(o)
    o = Bidirectional(LSTM(100,dropout=0.2,return_sequences=True, recurrent_dropout=0.2))(o)


    # Flatten
    o = Flatten(name='flatten')(o)
    
    # Dense layer
    o = Dense(64, activation=act, name='dense')(o)
    o = BatchNormalization(name='dense_norm')(o)
    o = Dropout(0.2, name='dropout')(o)
    
    # Predictions
    o = Dense(num_classes, activation='softmax', name='pred')(o)

    # Print network summary
    Model(inputs=x, outputs=o).summary()
    
    return Model(inputs=x, outputs=o)

# %%
mode = deep_cnn(input_shape, len(LABELS))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 128, 128, 1)       0
# _________________________________________________________________
# block1_conv (Conv2D)         (None, 128, 128, 32)      320
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 32)        0
# _________________________________________________________________
# block1_norm (BatchNormalizat (None, 64, 64, 32)        128
# _________________________________________________________________
# block2_conv (Conv2D)         (None, 64, 64, 32)        9248
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 32)        0
# _________________________________________________________________
# block2_norm (BatchNormalizat (None, 32, 32, 32)        128
# _________________________________________________________________
# block3_conv (Conv2D)         (None, 32, 32, 32)        9248
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 32)        0
# _________________________________________________________________
# block3_norm (BatchNormalizat (None, 16, 16, 32)        128
# _________________________________________________________________
# block4_conv (Conv2D)         (None, 16, 16, 32)        9248
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 32)          0
# _________________________________________________________________
# block4_norm (BatchNormalizat (None, 8, 8, 32)          128
# _________________________________________________________________
# block5_conv (Conv2D)         (None, 8, 8, 32)          9248
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 32)          0
# _________________________________________________________________
# block5_norm (BatchNormalizat (None, 4, 4, 32)          128
# _________________________________________________________________
# block6_conv (Conv2D)         (None, 4, 4, 32)          9248
# _________________________________________________________________
# block6_pool (MaxPooling2D)   (None, 2, 2, 32)          0
# _________________________________________________________________
# block6_norm (BatchNormalizat (None, 2, 2, 32)          128
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 64)             0
# _________________________________________________________________
# dense1 (Dense)               (None, 2, 64)             4160
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 2, 200)            132000
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 2, 200)            240800
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                25664
# _________________________________________________________________
# dense_norm (BatchNormalizati (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# pred (Dense)                 (None, 3)                 195
# =================================================================
# Total params: 450,403
# Trainable params: 449,891
# Non-trainable params: 512
# _________________________________________________________________

# %%
mode.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath="modeel.h5",
                               verbose=0, monitor = 'val_acc',
                               save_best_only=True)

# %%
history = mode.fit(x=X_train, y=y_train,
    epochs=100,
    batch_size=128,
    validation_data= (X_test, y_test),callbacks=[checkpointer])
# Out:
# Train on 1437 samples, validate on 360 samples
# Epoch 1/100
# 1437/1437 [==============================] - 10s 7ms/step - loss: 0.7436 - acc: 0.6875 - val_loss: 0.7498 - val_acc: 0.6611
# Epoch 2/100
# 1437/1437 [==============================] - 2s 2ms/step - loss: 0.4456 - acc: 0.8511 - val_loss: 1.4998 - val_acc: 0.5139
# Epoch 3/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0
100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0069 - acc: 0.9986 - val_loss: 0.3489 - val_acc: 0.9333
# Epoch 73/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.3113 - val_acc: 0.9417
# Epoch 74/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0033 - acc: 0.9986 - val_loss: 0.3468 - val_acc: 0.9361
# Epoch 75/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0286 - acc: 0.9916 - val_loss: 0.3992 - val_acc: 0.9361
# Epoch 76/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0153 - acc: 0.9944 - val_loss: 0.4240 - val_acc: 0.9139
# Epoch 77/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0054 - acc: 0.9986 - val_loss: 0.4331 - val_acc: 0.9444
# Epoch 78/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.3597 - val_acc: 0.9472
# Epoch 79/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0027 - acc: 0.9993 - val_loss: 0.3479 - val_acc: 0.9500
# Epoch 80/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0055 - acc: 0.9986 - val_loss: 0.3341 - val_acc: 0.9500
# Epoch 81/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 0.3784 - val_acc: 0.9500
# Epoch 82/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0036 - acc: 0.9986 - val_loss: 0.3272 - val_acc: 0.9417
# Epoch 83/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0059 - acc: 0.9986 - val_loss: 0.4011 - val_acc: 0.9389
# Epoch 84/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.8472 - val_acc: 0.7417
# Epoch 85/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0043 - acc: 0.9993 - val_loss: 0.3767 - val_acc: 0.9417
# Epoch 86/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0862 - acc: 0.9798 - val_loss: 5.0845 - val_acc: 0.4972
# Epoch 87/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0364 - acc: 0.9889 - val_loss: 3.4005 - val_acc: 0.5111
# Epoch 88/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0262 - acc: 0.9923 - val_loss: 5.0695 - val_acc: 0.4139
# Epoch 89/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0232 - acc: 0.9916 - val_loss: 0.4611 - val_acc: 0.9306
# Epoch 90/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0097 - acc: 0.9965 - val_loss: 0.6116 - val_acc: 0.9139
# Epoch 91/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0085 - acc: 0.9972 - val_loss: 0.6339 - val_acc: 0.9139
# Epoch 92/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0072 - acc: 0.9986 - val_loss: 0.4809 - val_acc: 0.9306
# Epoch 93/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.4132 - val_acc: 0.9389
# Epoch 94/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0039 - acc: 0.9993 - val_loss: 0.3520 - val_acc: 0.9472
# Epoch 95/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0085 - acc: 0.9979 - val_loss: 0.2650 - val_acc: 0.9556
# Epoch 96/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0121 - acc: 0.9965 - val_loss: 0.3693 - val_acc: 0.9444
# Epoch 97/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0617 - acc: 0.9840 - val_loss: 3.9425 - val_acc: 0.4194
# Epoch 98/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0621 - acc: 0.9798 - val_loss: 3.9690 - val_acc: 0.4222
# Epoch 99/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0178 - acc: 0.9944 - val_loss: 1.3024 - val_acc: 0.5583
# Epoch 100/100
# 1437/1437 [==============================] - 2s 1ms/step - loss: 0.0176 - acc: 0.9965 - val_loss: 1.6805 - val_acc: 0.5333

# %%
mode= load_model('modeel.h5')
scores = mode.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 95.56%

# %%
y_predpro = mode.predict(X_test,batch_size=32)

# %%
y_pred = np.argmax(y_predpro, axis=1)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

for i in LABELS:
    print(i ,'---', LABELS.index(i))

conf_matrix = confusion_matrix(labels_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix,  annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# English --- 0
# Yoruba --- 1
# Igbo --- 2

# %%
from sklearn.metrics import classification_report
print(classification_report(labels_test, y_pred, target_names=LABELS))
# Out:
#               precision    recall  f1-score   support
#
#      English       1.00      1.00      1.00       125
#       Yoruba       0.89      0.97      0.93       109
#         Igbo       0.97      0.90      0.93       126
#
#    micro avg       0.96      0.96      0.96       360
#    macro avg       0.95      0.96      0.95       360
# weighted avg       0.96      0.96      0.96       360
